# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Load the dataset

# %%
df= pd.read_csv(r"C:\Users\sanoj\Downloads\dynamic_pricing (1).csv")
df.head()
# Out:
#    Number_of_Riders  Number_of_Drivers Location_Category  \
# 0                90                 45             Urban
# 1                58                 39          Suburban
# 2                42                 31             Rural
# 3                89                 28             Rural
# 4                78                 22             Rural
#
#   Customer_Loyalty_Status  Number_of_Past_Rides  Average_Ratings  \
# 0                  Silver                    13             4.47
# 1                  Silver                    72             4.06
# 2                  Silver                     0             3.99
# 3                 Regular                    67             4.31
# 4                 Regular                    74             3.77
#
#   Time_of_Booking Vehicle_Type  Expected_Ride_Duration  \
# 0           Night      Premium                      90
# 1         Evening      Economy                      43
# 2       Afternoon      Premium                      76
# 3       Afternoon      Premium                     134
# 4       Afternoon      Economy                     149
#
#    Historical_Cost_of_Ride
# 0               284.257273
# 1               173.874753
# 2               329.795469
# 3               470.201232
# 4               579.681422

# %%
df.describe()
# Out:
#        Number_of_Riders  Number_of_Drivers  Number_of_Past_Rides  \
# count       1000.000000        1000.000000           1000.000000
# mean          60.372000          27.076000             50.031000
# std           23.701506          19.068346             29.313774
# min           20.000000           5.000000              0.000000
# 25%           40.000000          11.000000             25.000000
# 50%           60.000000          22.000000             51.000000
# 75%           81.000000          38.000000             75.000000
# max          100.000000          89.000000            100.000000
#
#        Average_Ratings  Expected_Ride_Duration  Historical_Cost_of_Ride
# count      1000.000000              1000.00000              1000.000000
# mean          4.257220                99.58800               372.502623
# std           0.435781                49.16545               187.158756
# min           3.500000                10.00000                25.993449
# 25%           3.870000                59.75000               221.365202
# 50%           4.270000               102.00000               362.019426
# 75%           4.632500               143.00000               510.497504
# max           5.000000               180.00000               836.116419

# %% [markdown]
# # Ratio Based Approach

# %% [markdown]
# ## Calculating Demand_Supply_Ratio and picking demand_supply_threshold = 2.3 arround the mean of Demand_Supply_Ratio
# * ### Higher Demand = when 'Demand_Supply_Ratio' > demand_supply_threshold (2.3) else Low-demand
# * ### Higher supply = when 'Demand_Supply_Ratio' < demand_supply_threshold (2.3) else Low-supply

# %%
df['Demand_Supply_Ratio'] = df['Number_of_Riders'] / df['Number_of_Drivers']
demand_supply_threshold = 2.3

df['Demand_class'] = np.where(df['Demand_Supply_Ratio'] > demand_supply_threshold, "Higher_demand", "Lower_demand")
df['Supply_class'] = np.where(df['Demand_Supply_Ratio'] < demand_supply_threshold, "Higher_supply", "Lower_supply")

df.iloc[:,[0,1,10,11,12]].sample(10)
# Out:
#      Number_of_Riders  Number_of_Drivers  Demand_Supply_Ratio   Demand_class  \
# 458                96                 27             3.555556  Higher_demand
# 933                96                 36             2.666667  Higher_demand
# 13                 36                 24             1.500000   Lower_demand
# 599                80                 67             1.194030   Lower_demand
# 124                26                 15             1.733333   Lower_demand
# 618                96                 48             2.000000   Lower_demand
# 917                87                 41             2.121951   Lower_demand
# 427                84                 21             4.000000  Higher_demand
# 75                 47                  9             5.222222  Higher_demand
# 33                 35                 24             1.458333   Lower_demand
#
#       Supply_class
# 458   Lower_supply
# 933   Lower_supply
# 13   Higher_supply
# 599  Higher_supply
# 124  Higher_supply
# 618  Higher_supply
# 917  Higher_supply
# 427   Lower_supply
# 75    Lower_supply
# 33   Higher_supply

# %% [markdown]
# ## calulation Base Price and Surge_charge based on supply demand ratio and demand_supply_factor
# * ### 1. Calculate base historical cost based on expected_Ride_duration
# * ### 2. Calculate rider-to-driver ratio
# * ### 3. Calculate demand-supply factor
# * ### 4. Defining a methode to Calculate supply_demand_surge and Apply the dynamic pricing formula

# %%
constant_rate = 3.5  # Define the base rate per unit of duration, this is arround mean of ratio of ('Historical_Cost_of_Ride'/'Expected_Ride_Duration')
demand_hike = 0.35  # This is how much demand increase the pricing

# Calculate base historical cost based on expected_Ride_duration
df['base_cost'] = df['Expected_Ride_Duration'] * constant_rate

# Calculate rider-to-driver ratio
df['rider_driver_ratio'] = df['Number_of_Riders'] / df['Number_of_Drivers']

# Calculate demand-supply factor
df['demand_supply_factor'] = df['rider_driver_ratio'] - 1
df['demand_supply_factor'] = df['demand_supply_factor'].apply(lambda x: min(x, 6))

# defining a methode to Calculate supply_demand_surge and Apply the dynamic pricing formula
def apply_surge(df):
    SD_surge_charge=0
    if (df['Demand_class']=='Higher_demand') & (df['Supply_class']=='Lower_supply'):
        SD_surge_charge = df['base_cost'] * (demand_hike * df['demand_supply_factor'])
    return SD_surge_charge

df['S/D_surge_charge'] = df.apply(apply_surge,axis=1)
df.head()
# Out:
#    Number_of_Riders  Number_of_Drivers Location_Category  \
# 0                90                 45             Urban
# 1                58                 39          Suburban
# 2                42                 31             Rural
# 3                89                 28             Rural
# 4                78                 22             Rural
#
#   Customer_Loyalty_Status  Number_of_Past_Rides  Average_Ratings  \
# 0                  Silver                    13             4.47
# 1                  Silver                    72             4.06
# 2                  Silver                     0             3.99
# 3                 Regular                    67             4.31
# 4                 Regular                    74             3.77
#
#   Time_of_Booking Vehicle_Type  Expected_Ride_Duration  \
# 0           Night      Premium                      90
# 1         Evening      Economy                      43
# 2       Afternoon      Premium                      76
# 3       Afternoon      Premium                     134
# 4       Afternoon      Economy                     149
#
#    Historical_Cost_of_Ride  Demand_Supply_Ratio   Demand_class   Supply_class  \
# 0               284.257273             2.000000   Lower_demand  Higher_supply
# 1               173.874753             1.487179   Lower_demand  Higher_supply
# 2               329.795469             1.354839   Lower_demand  Higher_supply
# 3               470.201232             3.178571  Higher_demand   Lower_supply
# 4               579.681422             3.545455  Higher_demand   Lower_supply
#
#    base_cost  rider_driver_ratio  demand_supply_factor  S/D_surge_charge
# 0      315.0            2.000000              1.000000          0.000000
# 1      150.5            1.487179              0.487179          0.000000
# 2      266.0            1.354839              0.354839          0.000000
# 3      469.0            3.178571              2.178571        357.612500
# 4      521.5            3.545455              2.545455        464.609091

# %% [markdown]
# ## Conditional Surge based on Vehical_Type and Time_of_booking && Location_Category Condition

# %%
def cal_surge_charge(df):
    surge_charge = 0
    if df['Vehicle_Type'] == 'Premium':
        if (df['Location_Category'] in ('Urban', 'Suburban')) & (df['Time_of_Booking'] in ('Evening', 'Night')):
            surge_charge = df['base_cost'] * 0.05 + df['base_cost'] * 0.02
    else:
        if (df['Location_Category'] in ('Urban', 'Suburban')) & (df['Time_of_Booking'] in ('Evening', 'Night')):
            surge_charge = df['base_cost'] * 0.025 + df['base_cost'] * 0.01
    return surge_charge

df['Surge_charge'] = df.apply(cal_surge_charge, axis=1)

# %%
df.sample(10)
# Out:
#      Number_of_Riders  Number_of_Drivers Location_Category  \
# 723                76                 35          Suburban
# 701                23                  5             Urban
# 241                88                 55             Rural
# 633                91                 53          Suburban
# 109                40                 15             Urban
# 415                94                 27          Suburban
# 429                25                 11             Urban
# 992                63                 31          Suburban
# 387                71                  7             Urban
# 214                49                 30             Rural
#
#     Customer_Loyalty_Status  Number_of_Past_Rides  Average_Ratings  \
# 723                 Regular                     8             4.89
# 701                    Gold                    92             3.71
# 241                 Regular                    56             4.00
# 633                    Gold                    67             4.56
# 109                 Regular                    90             3.62
# 415                  Silver                   100             3.60
# 429                  Silver                    92             3.91
# 992                  Silver                     2             3.81
# 387                    Gold                    31             4.83
# 214                  Silver                    86             3.62
#
#     Time_of_Booking Vehicle_Type  Expected_Ride_Duration  \
# 723       Afternoon      Premium                     138
# 701           Night      Economy                     105
# 241           Night      Premium                      26
# 633           Night      Economy                      50
# 109           Night      Premium                      42
# 415           Night      Premium                     172
# 429           Night      Economy                     115
# 992         Evening      Premium                     160
# 387         Morning      Premium                      60
# 214       Afternoon      Premium                      69
#
#      Historical_Cost_of_Ride  Demand_Supply_Ratio   Demand_class  \
# 723               406.589911             2.171429   Lower_demand
# 701               363.444776             4.600000  Higher_demand
# 241               159.606919             1.600000   Lower_demand
# 633               158.106723             1.716981   Lower_demand
# 109               211.527729             2.666667  Higher_demand
# 415               547.981462             3.481481  Higher_demand
# 429               310.154616             2.272727   Lower_demand
# 992               632.560142             2.032258   Lower_demand
# 387               292.746830            10.142857  Higher_demand
# 214               328.635369             1.633333   Lower_demand
#
#       Supply_class  base_cost  rider_driver_ratio  demand_supply_factor  \
# 723  Higher_supply      483.0            2.171429              1.171429
# 701   Lower_supply      367.5            4.600000              3.600000
# 241  Higher_supply       91.0            1.600000              0.600000
# 633  Higher_supply      175.0            1.716981              0.716981
# 109   Lower_supply      147.0            2.666667              1.666667
# 415   Lower_supply      602.0            3.481481              2.481481
# 429  Higher_supply      402.5            2.272727              1.272727
# 992  Higher_supply      560.0            2.032258              1.032258
# 387   Lower_supply      210.0           10.142857              6.000000
# 214  Higher_supply      241.5            1.633333              0.633333
#
#      S/D_surge_charge  Surge_charge
# 723          0.000000        0.0000
# 701        463.050000       12.8625
# 241          0.000000        0.0000
# 633          0.000000        6.1250
# 109         85.750000       10.2900
# 415        522.848148       42.1400
# 429          0.000000       14.0875
# 992          0.000000       39.2000
# 387        441.000000        0.0000
# 214          0.000000        0.0000

# %% [markdown]
# ## Calculating Total cost

# %%
df['New_cost']= df['base_cost'] + df['S/D_surge_charge'] + df['Surge_charge']
df.iloc[:,[0,1,9,10,11,12,13,16,17,18]].sample(10)
# Out:
#      Number_of_Riders  Number_of_Drivers  Historical_Cost_of_Ride  \
# 917                87                 41               158.891980
# 472                85                 65               770.070891
# 462                44                 11               104.752010
# 908                27                 12               279.268700
# 256                92                 37               434.571051
# 916                61                 39               230.143145
# 339                49                 14               633.496622
# 729                71                 41               614.636713
# 583                97                 25               332.229376
# 638                65                 51               588.136770
#
#      Demand_Supply_Ratio   Demand_class   Supply_class  base_cost  \
# 917             2.121951   Lower_demand  Higher_supply      129.5
# 472             1.307692   Lower_demand  Higher_supply      577.5
# 462             4.000000  Higher_demand   Lower_supply       63.0
# 908             2.250000   Lower_demand  Higher_supply      192.5
# 256             2.486486  Higher_demand   Lower_supply      360.5
# 916             1.564103   Lower_demand  Higher_supply      161.0
# 339             3.500000  Higher_demand   Lower_supply      458.5
# 729             1.731707   Lower_demand  Higher_supply      490.0
# 583             3.880000  Higher_demand   Lower_supply      353.5
# 638             1.274510   Lower_demand  Higher_supply      504.0
#
#      S/D_surge_charge  Surge_charge    New_cost
# 917          0.000000         0.000  129.500000
# 472          0.000000         0.000  577.500000
# 462         66.150000         0.000  129.150000
# 908          0.000000         0.000  192.500000
# 256        187.557432         0.000  548.057432
# 916          0.000000         0.000  161.000000
# 339        401.187500         0.000  859.687500
# 729          0.000000         0.000  490.000000
# 583        356.328000        24.745  734.573000
# 638          0.000000        35.280  539.280000

# %% [markdown]
# ## Revenue Before and after

# %%
print("Revenue before applying Dynamic_pricing -->",round(sum(df['Historical_Cost_of_Ride']),2))
print("Revenue after applying Dynamic_pricing-->",round(sum(df['New_cost']),2))
# Out:
# Revenue before applying Dynamic_pricing --> 372502.62
# Revenue after applying Dynamic_pricing--> 552298.01

# %%
diff=sum(df['New_cost'])-sum(df['Historical_Cost_of_Ride'])
print("Diffrenece of Revenue--> ", diff)
print("Revenue Percentage --> ", diff/sum(df['Historical_Cost_of_Ride'])*100)
# Out:
# Diffrenece of Revenue-->  179795.39090132003
# Revenue Percentage -->  48.26687911203326

# %% [markdown]
# ## Conclusion
# * ### Diffrenece of Revenue-->  179795.39
# * ### Revenue Percentage -->  48.26

# %%
filter=df['Demand_Supply_Ratio']>10
df[filter].head(10)
# Out:
#      Number_of_Riders  Number_of_Drivers Location_Category  \
# 49                 67                  6             Rural
# 88                 66                  6             Rural
# 94                 95                  7             Rural
# 153                51                  5             Urban
# 170                76                  7             Urban
# 197                75                  7          Suburban
# 216                88                  5             Urban
# 218                65                  5             Rural
# 232                87                  5             Urban
# 250                97                  7             Urban
#
#     Customer_Loyalty_Status  Number_of_Past_Rides  Average_Ratings  \
# 49                     Gold                    15             3.53
# 88                  Regular                    23             4.20
# 94                     Gold                    40             4.68
# 153                    Gold                     0             4.59
# 170                    Gold                    76             4.35
# 197                    Gold                   100             4.13
# 216                  Silver                    89             3.59
# 218                  Silver                    24             3.54
# 232                  Silver                    59             4.32
# 250                  Silver                    22             3.74
#
#     Time_of_Booking Vehicle_Type  Expected_Ride_Duration  \
# 49            Night      Economy                     123
# 88          Evening      Economy                      45
# 94          Evening      Economy                      95
# 153       Afternoon      Premium                      92
# 170         Morning      Economy                      72
# 197         Morning      Economy                     134
# 216           Night      Economy                      27
# 218           Night      Economy                     119
# 232           Night      Economy                      42
# 250       Afternoon      Premium                     147
#
#      Historical_Cost_of_Ride  Demand_Supply_Ratio   Demand_class  \
# 49                420.623911            11.166667  Higher_demand
# 88                173.157754            11.000000  Higher_demand
# 94                283.466443            13.571429  Higher_demand
# 153               320.857622            10.200000  Higher_demand
# 170               245.893571            10.857143  Higher_demand
# 197               453.376949            10.714286  Higher_demand
# 216                70.203803            17.600000  Higher_demand
# 218               301.403927            13.000000  Higher_demand
# 232               151.359301            17.400000  Higher_demand
# 250               441.746701            13.857143  Higher_demand
#
#      Supply_class  base_cost  rider_driver_ratio  demand_supply_factor  \
# 49   Lower_supply      430.5           11.166667                   6.0
# 88   Lower_supply      157.5           11.000000                   6.0
# 94   Lower_supply      332.5           13.571429                   6.0
# 153  Lower_supply      322.0           10.200000                   6.0
# 170  Lower_supply      252.0           10.857143                   6.0
# 197  Lower_supply      469.0           10.714286                   6.0
# 216  Lower_supply       94.5           17.600000                   6.0
# 218  Lower_supply      416.5           13.000000                   6.0
# 232  Lower_supply      147.0           17.400000                   6.0
# 250  Lower_supply      514.5           13.857143                   6.0
#
#      S/D_surge_charge  Surge_charge   New_cost
# 49             904.05        0.0000  1334.5500
# 88             330.75        0.0000   488.2500
# 94             698.25        0.0000  1030.7500
# 153            676.20        0.0000   998.2000
# 170            529.20        0.0000   781.2000
# 197            984.90        0.0000  1453.9000
# 216            198.45        3.3075   296.2575
# 218            874.65        0.0000  1291.1500
# 232            308.70        5.1450   460.8450
# 250           1080.45        0.0000  1594.9500

# %% [markdown]
# # Data Spliting and Model training

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import mean_absolute_percentage_error,mean_squared_error

# %%
x=df[['Demand_Supply_Ratio','Location_Category','Time_of_Booking','Vehicle_Type','Expected_Ride_Duration']] #Train column
y=df['New_cost'] #Target column

# %%
X_train_val, X_test, y_train_val, y_test = train_test_split(x, y, test_size=0.2, random_state=42)
X_train, X_val, y_train, y_val = train_test_split(X_train_val, y_train_val, test_size=0.25, random_state=42)

# %%
X_train
# Out:
#      Demand_Supply_Ratio Location_Category Time_of_Booking Vehicle_Type  \
# 876             1.126437          Suburban       Afternoon      Economy
# 326             1.700000             Urban         Morning      Premium
# 381             9.142857             Rural         Evening      Economy
# 853             1.282051             Urban         Morning      Premium
# 311             2.266667             Urban           Night      Premium
# ..                   ...               ...             ...          ...
# 118             4.043478          Suburban         Evening      Premium
# 334             3.700000             Urban       Afternoon      Economy
# 409             3.142857             Urban         Morning      Premium
# 225             7.571429             Urban           Night      Premium
# 482             3.052632             Urban         Evening      Economy
#
#      Expected_Ride_Duration
# 876                      13
# 326                     158
# 381                      64
# 853                     135
# 311                     134
# ..                      ...
# 118                     125
# 334                      44
# 409                      98
# 225                      10
# 482                      77
#
# [600 rows x 5 columns]

# %%
y_train
# Out:
# 876     45.500000
# 326    553.000000
# 381    694.400000
# 853    472.500000
# 311    501.830000
#           ...
# 118    934.157609
# 334    299.530000
# 409    600.250000
# 225    110.950000
# 482    472.546974
# Name: New_cost, Length: 600, dtype: float64

# %%
ohe = OneHotEncoder()
ohe.fit(x[['Location_Category','Time_of_Booking','Vehicle_Type']])
# Out:
# OneHotEncoder()

# %%
cat=ohe.categories_

# %%
column_trans = make_column_transformer((OneHotEncoder(categories=cat),
                                        ['Location_Category','Time_of_Booking','Vehicle_Type']),
                                        remainder='passthrough')

# %%
rf=RandomForestRegressor()                                    
pipe=make_pipeline(column_trans,rf)
pipe.fit(X_train,y_train)
# Out:
# c:\Users\sanoj\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\compose\_column_transformer.py:1623: FutureWarning:
# The format of the columns of the 'remainder' transformer in ColumnTransformer.transformers_ will change in version 1.7 to match the format of the other transformers.
# At the moment the remainder columns are stored as indices (of type int). With the same ColumnTransformer configuration, in the future they will be stored as column names (of type str).
# To use the new behavior now and suppress this warning, use ColumnTransformer(force_int_remainder_cols=False).
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(categories=[array(['Rural', 'Suburban', 'Urban'], dtype=object),
#                                                                             array(['Afternoon', 'Evening', 'Morning', 'Night'], dtype=object),
#                                                                             array(['Economy', 'Premium'], dtype=object)]),
#                                                   ['Location_Category',
#                                                    'Time_of_Booking',
#                                                    'Vehicle_Type'])])),
#                 ('randomforestregressor', RandomForestRegressor())])

# %%
y_pred_rf=pipe.predict(X_test)
print(y_pred_rf)
# Out:
# [ 915.4596156   657.08323333 1033.74770036  317.28935     166.70119776
#   634.99466688  413.4604587   155.839425    810.96457616  230.39685252
#   334.8758      216.23        135.1618678   976.60725276  394.3723
#   375.64905     612.067925    693.45123837  154.28985066  455.96070383
#   672.51753769  124.73459356  330.72421726  376.98675     356.74703961
#   612.42125     159.701325   1352.75130189  196.14336875 1156.25918333
#   336.08855      88.5206      411.6616      148.009225    613.17265633
#   338.551325    132.68338125  357.43554904  618.24598476  339.920525
#   915.3576401   839.92581349 1401.7639684   972.45887696 1829.04145278
#   398.126225    530.75895623 1069.54291682  306.68715     638.36966459
#   535.50504982  127.57955     515.45445     207.7355      161.73359028
#   549.97825973  365.369025   1445.66540386  884.67301088  516.2213
#   706.94834857  592.71386111  482.649125    403.02605     897.0479656
#   535.51818942  402.91850278  398.58471532  529.73398318  217.69895
#   720.56004364  161.95625657  796.89070232  898.63400709  325.596425
#   411.971875    160.03684375 1245.03634053 1695.5195149  1221.51088667
#  1236.23598194  516.112975   1183.3847337   102.6956      466.4646
#   560.1631      208.45545      72.9617     1392.41323914 1019.81148293
#   510.32042996  243.97108643  665.12210829 1208.27845833  662.72882218
#   803.56821588 1588.2154325   429.69289402  657.1193484   601.725775
#   184.40953846  231.2898      321.19745     564.76238142  524.082475
#   362.64489419  894.88838268  594.35635     519.0955      129.255
#   426.38015     389.137       607.8044      169.640625     64.6569
#    87.58026932  244.52971884  568.91952624  796.49209824  256.07995
#   397.30836746  211.97937568  306.47845104  222.0953      722.06143396
#    76.5149      679.91970688  703.69370909  594.3322      132.78916875
#   527.262575   1327.46710475  960.78949258   38.37785     402.964975
#   547.878625    424.6767      353.115      1198.16863711  424.06174095
#   612.82967757   40.2171      944.98211861  829.23232446  383.1503117
#   663.46299957  633.4069      407.1648      690.64234197  180.8086
#   597.022125   1724.43621763  335.875925    413.16753534  398.2636
#   130.72611876 1489.97634457  579.502175    244.3588       42.60515
#  1639.73154423  699.36830011 1025.28192083  359.83551643  113.085875
#   801.96535722  587.238575    981.5959058   711.56458022  608.84075
#   742.67444342  436.435125   1094.81617791  697.54718336  326.80321127
#   377.3378      968.62022499  252.989625     39.303075    337.35801795
#   824.48751993  105.548275    456.887375   1517.85967791  600.59990279
#   478.07795     233.4535      199.51674405  510.323275    131.40501407
#   112.8442     1340.3635041   584.3705     1282.85788995  619.060925
#   668.04160739  379.376375    448.984725    596.787625    147.0455    ]

# %% [markdown]
# ### Model Evaluation & Check prediction

# %%
# 1. Model evaluation on validation Data
y_val_pred_rf = pipe.predict(X_val)
mape = mean_absolute_percentage_error(y_val,y_val_pred_rf)
r2 = r2_score(y_val,y_val_pred_rf)
print("Error of RandomForest Regression Model = %.2f"%(mape*100),'%')
print("Accuracy of RandomForest Regression Model = %.2f"%((1 - mape)*100),'%')
print("R2 score of RandomForest Regression = %.2f"%(r2))
# Out:
# Error of RandomForest Regression Model = 3.93 %
# Accuracy of RandomForest Regression Model = 96.07 %
# R2 score of RandomForest Regression = 0.99

# %%
# 2. Model evaluation on Test Data
y_test_pred_rf = pipe.predict(X_test)
test_mse = mean_squared_error(y_test, y_test_pred_rf)
test_r2 = r2_score(y_test, y_test_pred_rf)
print("Mean square error :", test_mse)
print("R2 score of RandomForestr Regression on test data:", test_r2)
# Out:
# Mean square error : 25804.010772131278
# R2 score of RandomForestr Regression on test data: 0.8308779931645754

# %%
#using Linearregression
lr=LinearRegression()                                    
pipe=make_pipeline(column_trans,lr)
pipe.fit(X_train,y_train)

y_pred_lr=pipe.predict(X_test)
print(y_pred_lr)
# Out:
# [ 725.49985318  508.1060693   988.29705641  393.26549241  318.97656193
#   531.98143912  423.53447011  119.30788357  693.75509236  169.27977397
#   398.63716732  210.36750737  193.75497913  889.54894577  497.90395848
#   500.94705098  880.32441075  625.99665575  116.33528796  451.19424188
#   614.82082844  291.05957571  297.44714832  465.99765218  291.73430176
#   914.86394215   99.02837815 1400.26007905  203.81191271 1115.29983168
#   377.38545155   24.37875791  543.65000518  111.74637726  528.84416851
#   374.28285041  121.44603573  297.59227745  515.23845114  462.21432185
#   876.56109658  815.45941023 1008.81681601  949.42843104 1314.13789469
#   516.99502246  422.34182859  973.97749499  335.00744433  556.77384055
#   450.69908446   84.22266332  662.45194721  249.6198604   134.94326023
#   451.84849959  422.47184824 1032.20481351  875.95829501  721.90047544
#   646.89450429  550.647363    636.85153405  582.24481034  739.26236395
#   489.74335188  513.95178678  373.04786679  488.90856772  236.05905468
#   635.79575089   84.7651164   912.73370286  885.97408323  390.97058731
#   516.20376835  108.54358853 1034.98128846 1309.75241291 1000.05612908
#  1192.45537501  686.99607264  947.69234903   17.07675902  615.03695592
#   767.76501747  226.60061547   18.72403359  987.52488447  819.39929077
#   482.38420381  235.61045161  566.65963983 1352.44096944  590.74359767
#   820.53028797 1099.33488305  770.83627473  586.60304471  859.41815356
#   152.95309455  208.65416968  378.61126062  524.71774714  673.52274957
#   297.58127213  864.12245942  874.18080666  670.67276092  146.6718127
#   597.10888122  437.07211951  883.18164075  169.23879757  -55.59241626
#   -46.242007    281.73224034  451.62881339  789.26755813  207.54361486
#   310.1307964   171.02250251  261.16195755  219.79074875  641.89770266
#   -42.8906545   605.0221181   880.03624999  812.62147934   65.89231429
#   690.88437626  896.0816116   942.44552214  -99.66609388  525.43005968
#   721.83530906  537.48157594  450.35118661  975.46121365  383.55527566
#   566.83625875  -26.05342887  916.51265374  739.39043769  331.63817703
#   597.96464967  882.68225494  547.73870968  637.35623451  217.044136
#   840.6390455  1165.69734982  397.72155442  558.74029091  535.64274537
#   168.53741741 1078.23583524  846.51278529  284.82762865 -114.04212966
#  1205.18551191  617.3110958   849.44839191  471.6990071     9.1243251
#   778.26289592  838.53740981 1027.44060231  901.32648605  846.46909286
#   654.46838984  576.75272121  931.34598303  595.78299392  348.17692519
#   439.51177291  835.63705089  332.73458449 -102.31952011  533.33770098
#   904.01804631   24.69253718  590.32947674 1060.03620779  478.61282797
#   645.79901599  236.1344639   112.1009901   754.05375716  124.60352389
#    10.5819983  1052.3933748   793.00953416  959.46523749  840.67905225
#   579.58472559  452.33937408  584.427814    821.71185302   96.63419749]

# %% [markdown]
# ### Model Evaluation & Check prediction

# %%
# 1. Model evaluation on validation Data
y_val_pred_lr = pipe.predict(X_val)
mape = mean_absolute_percentage_error(y_val,y_val_pred_lr)
r2 = r2_score(y_val,y_val_pred_lr)
print("Error of Linear Regression Model = %.2f"%(mape*100),'%')
print("Accuracy of Linear Regression Model = %.2f"%((1 - mape)*100),'%')
print("R2 score of Linear Regression = %.2f"%(r2))
# Out:
# Error of Linear Regression Model = 29.48 %
# Accuracy of Linear Regression Model = 70.52 %
# R2 score of Linear Regression = 0.81

# %%
# 2. Model evaluation on Test Data
y_test_pred_lr = pipe.predict(X_test)
test_mse = mean_squared_error(y_test, y_test_pred_lr)
test_r2 = r2_score(y_test, y_test_pred_lr)
print("Mean square error :", test_mse)
print("R2 score of Linear Regression on test data:", test_r2)
# Out:
# Mean square error : 25804.010772131278
# R2 score of Linear Regression on test data: 83.08779931645755

# %%
results_df = pd.DataFrame(X_test, columns=x.columns)
results_df['Actual'] = y_test
results_df['Predicted_RandomForest'] = y_pred_rf
results_df['Predicted_LinearRegression'] = y_pred_lr
results_df['Error_RF'] = y_pred_rf-y_test
results_df['Error_LR'] = y_pred_lr-y_test
results_df.to_csv("test_results.csv", index=False)
